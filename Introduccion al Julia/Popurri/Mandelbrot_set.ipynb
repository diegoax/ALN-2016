# %%
using PyPlot

# %%
# función que determina conjunto de mandelbrot c tales 
# c,c^2+c,(c^2+c)^2+c,... acotada

function mandelbrot(z,c; maxiter=300)
    for n = 1:maxiter
        if abs2(z) > 4
            return n-1
        end
        z = z*z + c
    end
    return maxiter
end
# Out:
# mandelbrot (generic function with 1 method)

# %%
@time m = [ mandelbrot(complex(r,i),complex(r,i)) for i=1:-.002:-1, r=-1.5:.002:1.5 ];
# Out:
#   0.592889 seconds (2 allocations: 11.463 MB)

# %%
get_cmap("RdGy")
# Out:
# ColorMap "RdGy"

# %%
imshow(m, cmap="RdGy", extent=[-1.5,1.5,-1,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa818328e90>)
# PyObject <matplotlib.image.AxesImage object at 0x7fa8131c0a50>

# %%
@time m = [ mandelbrot(complex(r,i),complex(0.4,0.5)) for i=1:-.002:-1, r=-1.5:.002:1.5 ];
# Out:
#   0.047671 seconds (2 allocations: 11.463 MB)

# %%
imshow(m, cmap="RdGy", extent=[-1.5,1.5,-1,1])
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fa8131b2a50>)
# PyObject <matplotlib.image.AxesImage object at 0x7fa812ff2110>
